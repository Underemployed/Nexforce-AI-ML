# %% [markdown]
# <a href="https://colab.research.google.com/github/Underemployed/Nexforce-AI-ML/blob/main/nexforce_ai_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nexforce ai ml/SOCR-HeightWeight.csv")

# %%
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %%
df.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000

# %%
df.dtypes
# Out:
# Index               int64
# Height(Inches)    float64
# Weight(Pounds)    float64
# dtype: object

# %%
mean_height = df['Height(Inches)'].mean()
mean_weight = df['Weight(Pounds)'].mean()

median_height = df['Height(Inches)'].median()
median_weight = df['Weight(Pounds)'].median()

mode_height = df['Height(Inches)'].mode()[0]
mode_weight = df['Weight(Pounds)'].mode()[0]

print("Mean Height: ", mean_height)
print("Median Height: ", median_height)
print("Mode Height: ", mode_height)
print(30*"-")
print("Mean Weight: ", mean_weight)
print("Median Weight: ", median_weight)
print("Mode Weight: ", mode_weight)
# Out:
# Mean Height:  67.99311359679999
# Median Height:  67.9957
# Mode Height:  65.65796
# ------------------------------
# Mean Weight:  127.07942116080001
# Median Weight:  127.15775
# Mode Weight:  124.7975
